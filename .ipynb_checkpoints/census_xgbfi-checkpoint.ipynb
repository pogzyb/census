# %%
# data prep
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, KFold
from sklearn.decomposition import PCA, TruncatedSVD

# algorithmns
import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# visualizations
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# read in data

# through means of my own preparation, column names are saved in a txt file
with open('columns.txt','r') as cols:
    cols = cols.read().rstrip().split("\n")
    
# if necessary check cols with a print
# print(cols)

# read in train and test
train = pd.read_csv('census/census-income.data', na_values=['?',' ',' ?',' ?',' ? ',''], names=cols)
test = pd.read_csv('census/census-income.test', na_values=['?',' ',' ?',' ?',' ? ',''], names=cols)

# check shapes
for ds in [train, test]:
    print("Rows: {} Columns: {}".format(*ds.shape))
# Out:
# Rows: 199523 Columns: 42
# Rows: 99762 Columns: 42

# %%
# fix target in training set
train.target = train.target.apply(lambda x: int(x.replace(".","").strip("+").replace(" ","")))
# looks good: type int and (-) are represented
train.target.sample(5)
# Out:
# 72959   -50000
# 47147    50000
# 96629   -50000
# 48268   -50000
# 50924   -50000
# Name: target, dtype: int64

# %%
# check the proportionals of the target variable
vc = pd.DataFrame(train.target.value_counts())
vc['%'] = np.round((vc['target'] / len(train) * 100), 2)
vc.loc['total'] = vc.sum()
# highly imbalanced dataset
vc
# Out:
#           target       %
# -50000  187141.0   93.79
# 50000    12382.0    6.21
# total   199523.0  100.00

# %%
# descriptive features that I think are important
def aboutData(df):
    t = pd.DataFrame(df.isnull().sum(), columns=['#NA'])
    t['#Count'] = len(df) - t['#NA']
    t['#Distinct'] = df.nunique()
    t['#NotInUniverse'] = df.apply(lambda x: np.sum(x == ' Not in universe'), axis=0)
    t['dtype'] = df.dtypes
    t['skew'] = df.skew()
    return t

# ignore - pd.concat if you'd like to put the entire dataset through the func and
# sanity checking myself
# pd.concat([train,test], ignore_index=True)
# for col in cols:
#     if train[col].dtype == 'object':
#         nius = len(train[train[col] == ' Not in universe'])
#         print("Column: {} \tNumber of NIU: {}".format(col, nius))

info = aboutData(train)
info
# Out:
#                                               #NA  #Count  #Distinct  \
# age                                             0  199523         91
# class of worker                                 0  199523          9
# detailed industry recode                        0  199523         52
# detailed occupation recode                      0  199523         47
# education                                       0  199523         17
# wage per hour                                   0  199523       1240
# enroll in edu inst last wk                      0  199523          3
# marital stat                                    0  199523          7
# major industry code                             0  199523         24
# major occupation code                           0  199523         15
# race                                            0  199523          5
# hispanic origin                                 0  199523         10
# sex                                             0  199523          2
# member of a labor union                         0  199523          3
# reason for unemployment                         0  199523          6
# full or part time employment stat               0  199523          8
# capital gains                                   0  199523        132
# capital losses                                  0  199523        113
# dividends from stocks                           0  199523       1478
# tax filer stat                                  0  199523          6
# region of previous residence                    0  199523          6
# state of previous residence                   708  198815         50
# detailed household and family stat              0  199523         38
# detailed household summary in household         0  199523          8
# instance weight                                 0  199523      99800
# migration code-change in msa                99696   99827          9
# migration code-change in reg                99696   99827          8
# migration code-move within reg              99696   99827          9
# live in this house 1 year ago                   0  199523          3
# migration prev res in sunbelt               99696   99827          3
# num persons worked for employer                 0  199523          7
# family members under 18                         0  199523          5
# country of birth father                      6713  192810         42
# country of birth mother                      6119  193404         42
# country of birth self                        3393  196130         42
# citizenship                                     0  199523          5
# own business or self employed                   0  199523          3
# fill inc questionnaire for veteran's admin      0  199523          3
# veterans benefits                               0  199523          3
# weeks worked in year                            0  199523         53
# year                                            0  199523          2
# target                                          0  199523          2
#
#                                             #NotInUniverse    dtype       skew
# age                                                      0    int64   0.373290
# class of worker                                     100245   object        NaN
# detailed industry recode                                 0    int64   0.516688
# detailed occupation recode                               0    int64   0.829238
# education                                                0   object        NaN
# wage per hour                                            0    int64   8.935097
# enroll in edu inst last wk                          186943   object        NaN
# marital stat                                             0   object        NaN
# major industry code                                      0   object        NaN
# major occupation code                               100684   object        NaN
# race                                                     0   object        NaN
# hispanic origin                                          0   object        NaN
# sex                                                      0   object        NaN
# member of a labor union                             180459   object        NaN
# reason for unemployment                             193453   object        NaN
# full or part time employment stat                        0   object        NaN
# capital gains                                            0    int64  18.990822
# capital losses                                           0    int64   7.632565
# dividends from stocks                                    0    int64  27.786502
# tax filer stat                                           0   object        NaN
# region of previous residence                        183750   object        NaN
# state of previous residence                         183750   object        NaN
# detailed household and family stat                       0   object        NaN
# detailed household summary in household                  0   object        NaN
# instance weight                                          0  float64   1.432733
# migration code-change in msa                          1516   object        NaN
# migration code-change in reg                          1516   object        NaN
# migration code-move within reg                        1516   object        NaN
# live in this house 1 year ago                            0   object        NaN
# migration prev res in sunbelt                        84054   object        NaN
# num persons worked for employer                          0    int64   0.751561
# family members under 18                             144232   object        NaN
# country of birth father                                  0   object        NaN
# country of birth mother                                  0   object        NaN
# country of birth self                                    0   object        NaN
# citizenship                                              0   object        NaN
# own business or self employed                            0    int64   2.912744
# fill inc questionnaire for veteran's admin          197539   object        NaN
# veterans benefits                                        0    int64  -1.200994
# weeks worked in year                                     0    int64   0.210169
# year                                                     0    int64   0.001313
# target                                                   0    int64   3.630471

# %%
# missing values and information
info.loc[info['#NA'] > 0]
# - high disproportions of 'Not in universe' values: most likely drop
# - half of migration code variables are missing: most likely drop
# - some NAs in the country of birth columns: impute/feature engineer
# Out:
#                                   #NA  #Count  #Distinct  #NotInUniverse  \
# state of previous residence       708  198815         50          183750
# migration code-change in msa    99696   99827          9            1516
# migration code-change in reg    99696   99827          8            1516
# migration code-move within reg  99696   99827          9            1516
# migration prev res in sunbelt   99696   99827          3           84054
# country of birth father          6713  192810         42               0
# country of birth mother          6119  193404         42               0
# country of birth self            3393  196130         42               0
#
#                                  dtype  skew
# state of previous residence     object   NaN
# migration code-change in msa    object   NaN
# migration code-change in reg    object   NaN
# migration code-move within reg  object   NaN
# migration prev res in sunbelt   object   NaN
# country of birth father         object   NaN
# country of birth mother         object   NaN
# country of birth self           object   NaN

# %%
# Going to drop cols with too many 'not in universe' values
drops = info[info['#NotInUniverse'] > 80000].index.tolist()
drops
# Pause work on missing values for now
# Proceed with EDA
# Out:
# ['class of worker',
#  'enroll in edu inst last wk',
#  'major occupation code',
#  'member of a labor union',
#  'reason for unemployment',
#  'region of previous residence',
#  'state of previous residence',
#  'migration prev res in sunbelt',
#  'family members under 18',
#  "fill inc questionnaire for veteran's admin"]

# %%
# EDA
# columns into groups by types

# special cases that are int/float in the dataset, but should be treated as categorical
spcase = train.columns[train.columns.str.contains('recode')].tolist()
spcase.extend(['year','own business or self employed','veterans benefits'])

# extract dtypes from columns
nomial = train.select_dtypes(include=['object']).columns.tolist()
nomial.extend(spcase)
continuous = train.select_dtypes(include=['int','float']).columns.tolist()
continuous = [x for x in continuous if x not in spcase]

print("nomials ({}) : {}\n".format(len(nomial), nomial))
print("continuous ({}) : {}\n".format(len(continuous), continuous))
# Out:
# nomials (33) : ['class of worker', 'education', 'enroll in edu inst last wk', 'marital stat', 'major industry code', 'major occupation code', 'race', 'hispanic origin', 'sex', 'member of a labor union', 'reason for unemployment', 'full or part time employment stat', 'tax filer stat', 'region of previous residence', 'state of previous residence', 'detailed household and family stat', 'detailed household summary in household', 'migration code-change in msa', 'migration code-change in reg', 'migration code-move within reg', 'live in this house 1 year ago', 'migration prev res in sunbelt', 'family members under 18', 'country of birth father', 'country of birth mother', 'country of birth self', 'citizenship', "fill inc questionnaire for veteran's admin", 'detailed industry recode', 'detailed occupation recode', 'year', 'own business or self employed', 'veterans benefits']
#
# continuous (9) : ['age', 'wage per hour', 'capital gains', 'capital losses', 'dividends from stocks', 'instance weight', 'num persons worked for employer', 'weeks worked in year', 'target']

# %%
# nomial features by target
for col in
