# %%
# data prep
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.metrics import roc_auc_score, recall_score
from sklearn.decomposition import PCA, TruncatedSVD

# basic algorithmns
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# visualizations
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# read in data

# through means of my own preparation, column names are saved in a txt file
with open('columns.txt','r') as cols:
    cols = cols.read().rstrip().split("\n")
    
# if necessary check cols with a print
# print(cols)

# read in train and test
train = pd.read_csv('census/census-income.data', na_values=['?',' ',' ?',' ?',' ? ',''], names=cols)
test = pd.read_csv('census/census-income.test', na_values=['?',' ',' ?',' ?',' ? ',''], names=cols)

train = pd.concat([train,test], ignore_index=True)

# check shapes
for ds in [train, test]:
    print("Rows: {} Columns: {}".format(*ds.shape))
# Out:
# Rows: 299285 Columns: 42
# Rows: 99762 Columns: 42

# %%
# fix target in training set
train.target = train.target.apply(lambda x: int(x.replace(".","").strip("+").replace(" ","")))
# looks good: type int and (-) are represented
train.target.sample(5)
# Out:
# 271559   -50000
# 67842    -50000
# 251948   -50000
# 44464    -50000
# 101682   -50000
# Name: target, dtype: int64

# %%
# check the proportionals of the target variable
vc = pd.DataFrame(train.target.value_counts())
vc['%'] = np.round((vc['target'] / len(train) * 100), 2)
vc.loc['total'] = vc.sum()
# highly imbalanced dataset
vc
# Out:
#           target      %
# -50000  280717.0   93.8
# 50000    18568.0    6.2
# total   299285.0  100.0

# %%
# descriptive features that I think are important
def aboutData(df):
    t = pd.DataFrame(df.isnull().sum(), columns=['#NA'])
    t['#Count'] = len(df) - t['#NA']
    t['#Distinct'] = df.nunique()
    # explanation of the #notinuniverse count later in EDA
    t['#NotInUniverse'] = df.apply(lambda x: np.sum(x == ' Not in universe'), axis=0)
    t['dtype'] = df.dtypes
    t['skew'] = df.skew()
    return t

# ignore - pd.concat if you'd like to put the entire dataset through the func and
# sanity checking myself
# pd.concat([train,test], ignore_index=True)
# for col in cols:
#     if train[col].dtype == 'object':
#         nius = len(train[train[col] == ' Not in universe'])
#         print("Column: {} \tNumber of NIU: {}".format(col, nius))

info = aboutData(train)
info
# Out:
#                                                #NA  #Count  #Distinct  \
# age                                              0  299285         91
# class of worker                                  0  299285          9
# detailed industry recode                         0  299285         52
# detailed occupation recode                       0  299285         47
# education                                        0  299285         17
# wage per hour                                    0  299285       1425
# enroll in edu inst last wk                       0  299285          3
# marital stat                                     0  299285          7
# major industry code                              0  299285         24
# major occupation code                            0  299285         15
# race                                             0  299285          5
# hispanic origin                                  0  299285         10
# sex                                              0  299285          2
# member of a labor union                          0  299285          3
# reason for unemployment                          0  299285          6
# full or part time employment stat                0  299285          8
# capital gains                                    0  299285        133
# capital losses                                   0  299285        114
# dividends from stocks                            0  299285       1675
# tax filer stat                                   0  299285          6
# region of previous residence                     0  299285          6
# state of previous residence                   1038  298247         50
# detailed household and family stat               0  299285         38
# detailed household summary in household          0  299285          8
# instance weight                                  0  299285     123232
# migration code-change in msa                149642  149643          9
# migration code-change in reg                149642  149643          8
# migration code-move within reg              149642  149643          9
# live in this house 1 year ago                    0  299285          3
# migration prev res in sunbelt               149642  149643          3
# num persons worked for employer                  0  299285          7
# family members under 18                          0  299285          5
# country of birth father                      10142  289143         42
# country of birth mother                       9191  290094         42
# country of birth self                         5157  294128         42
# citizenship                                      0  299285          5
# own business or self employed                    0  299285          3
# fill inc questionnaire for veteran's admin       0  299285          3
# veterans benefits                                0  299285          3
# weeks worked in year                             0  299285         53
# year                                             0  299285          2
# target                                           0  299285          2
#
#                                             #NotInUniverse    dtype       skew
# age                                                      0    int64   0.372785
# class of worker                                     150324   object        NaN
# detailed industry recode                                 0    int64   0.515946
# detailed occupation recode                               0    int64   0.827236
# education                                                0   object        NaN
# wage per hour                                            0    int64   8.878780
# enroll in edu inst last wk                          280367   object        NaN
# marital stat                                             0   object        NaN
# major industry code                                      0   object        NaN
# major occupation code                               150967   object        NaN
# race                                                     0   object        NaN
# hispanic origin                                          0   object        NaN
# sex                                                      0   object        NaN
# member of a labor union                             270742   object        NaN
# reason for unemployment                             290085   object        NaN
# full or part time employment stat                        0   object        NaN
# capital gains                                            0    int64  19.090569
# capital losses                                           0    int64   7.685924
# dividends from stocks                                    0    int64  27.144287
# tax filer stat                                           0   object        NaN
# region of previous residence                        275818   object        NaN
# state of previous residence                         275818   object        NaN
# detailed household and family stat                       0   object        NaN
# detailed household summary in household                  0   object        NaN
# instance weight                                          0  float64   1.439617
# migration code-change in msa                          2239   object        NaN
# migration code-change in reg                          2239   object        NaN
# migration code-move within reg                        2239   object        NaN
# live in this house 1 year ago                            0   object        NaN
# migration prev res in sunbelt                       126176   object        NaN
# num persons worked for employer                          0    int64   0.752317
# family members under 18                             216626   object        NaN
# country of birth father                                  0   object        NaN
# country of birth mother                                  0   object        NaN
# country of birth self                                    0   object        NaN
# citizenship                                              0   object        NaN
# own business or self employed                            0    int64   2.901533
# fill inc questionnaire for veteran's admin          296274   object        NaN
# veterans benefits                                        0    int64  -1.206282
# weeks worked in year                                     0    int64   0.210018
# year                                                     0    int64   0.000007
# target                                                   0    int64   3.631060

# %%
# missing values and information
info.loc[info['#NA'] > 0]
# - high disproportions of 'Not in universe' values: most likely drop
# - half of migration code variables are missing: most likely drop
# - some NAs in the country of birth columns: impute/feature engineer
# Out:
#                                    #NA  #Count  #Distinct  #NotInUniverse  \
# state of previous residence       1038  298247         50          275818
# migration code-change in msa    149642  149643          9            2239
# migration code-change in reg    149642  149643          8            2239
# migration code-move within reg  149642  149643          9            2239
# migration prev res in sunbelt   149642  149643          3          126176
# country of birth father          10142  289143         42               0
# country of birth mother           9191  290094         42               0
# country of birth self             5157  294128         42               0
#
#                                  dtype  skew
# state of previous residence     object   NaN
# migration code-change in msa    object   NaN
# migration code-change in reg    object   NaN
# migration code-move within reg  object   NaN
# migration prev res in sunbelt   object   NaN
# country of birth father         object   NaN
# country of birth mother         object   NaN
# country of birth self           object   NaN

# %%
# Going to drop cols with too many 'not in universe' values
drops = info[info['#NotInUniverse'] > 80000].index.tolist()
drops
# Pause work on missing values for now
# Proceed with EDA
# Out:
# ['class of worker',
#  'enroll in edu inst last wk',
#  'major occupation code',
#  'member of a labor union',
#  'reason for unemployment',
#  'region of previous residence',
#  'state of previous residence',
#  'migration prev res in sunbelt',
#  'family members under 18',
#  "fill inc questionnaire for veteran's admin"]

# %%
# it's a valid assumption that individuals under 16
# are not making +50k a year or there is a large percent of these individuals in the working class
# to be removed...
minors = []
for n in np.arange(16):
    indices = train.loc[train.age == n,'age'].index.tolist()
    minors.extend(indices)

# Combine all our dropped features into a list
code_migs = train.columns[train.columns.str.contains('code-')].tolist()
drops.extend(code_migs)
drops.append('year')
# modify df's
train = train.drop(drops, axis=1)
# remove minors from training
train = train.drop(minors)
test = test.drop(drops, axis=1)

# %%
# EDA
# columns into groups by types

# special cases that are int/float in the dataset, but should be treated as categorical
spcase = train.columns[train.columns.str.contains('recode')].tolist()
spcase.extend(['year','own business or self employed','veterans benefits'])

# extract dtypes from columns
nomial = train.select_dtypes(include=['object']).columns.tolist()
nomial.extend(spcase)
continuous = train.select_dtypes(include=['int','float']).columns.tolist()
continuous = [x for x in continuous if x not in spcase]

print("nomials ({}) : {}\n".format(len(nomial), nomial))
print("continuous ({}) : {}\n".format(len(continuous), continuous))
# Out:
# nomials (20) : ['education', 'marital stat', 'major industry code', 'race', 'hispanic origin', 'sex', 'full or part time employment stat', 'tax filer stat', 'detailed household and family stat', 'detailed household summary in household', 'live in this house 1 year ago', 'country of birth father', 'country of birth mother', 'country of birth self', 'citizenship', 'detailed industry recode', 'detailed occupation recode', 'year', 'own business or self employed', 'veterans benefits']
#
# continuous (9) : ['age', 'wage per hour', 'capital gains', 'capital losses', 'dividends from stocks', 'instance weight', 'num persons worked for employer', 'weeks worked in year', 'target']

# %%
# nomial countplots

# plt.figure(figsize=(25,55));

# for i,col in enumerate(nomial):
#     plt.subplot(11,3,i+1);
#     sns.countplot(y=col, data=train);

# see a lot of not in universe affecting variables, so at this point the aboutData function was modified

# %%
# medium

# plt.figure(figsize=(45,120));
# md_nomials = []
# for col in nomial:
#     if (info.loc[col,'#Distinct'] >= 8) and (info.loc[col,'#Distinct'] <=15):
#         md_nomials.append(col)

# for i,col in enumerate(md_nomials):
#     plt.subplot(len(md_nomials),3,i+1);
#     sns.countplot(y=col, data=train, hue='target');
#     plt.xticks(rotation=25);

# %%
# target compared with some nomial

# plt.figure(figsize=(45,120));
# sm_nomials = []
# for col in nomial:
#     if info.loc[col,'#Distinct'] < 8:
#         sm_nomials.append(col)

# for i,col in enumerate(sm_nomials):
#     plt.subplot(len(sm_nomials),3,i+1);
#     sns.countplot(y=col, data=train, hue='target');
#     plt.xticks(rotation=25);
    
# year doesn't add anything to the model - can be dropped
# male and married = indicators of +50k
# tax filer stat = good indicator

# %%
# continous hists and stripplots
# plt.figure(figsize=(25,50))
# for i,col in enumerate(continuous):
#     plt.subplot(len(continuous),3,i+1);
#     above = train.loc[train['target'] == 50000,col]
#     below = train.loc[train['target'] == -50000,col]
#     plt.hist(below, bins=25, alpha=0.5);
#     plt.hist(above, bins=25, alpha=0.5);
#     plt.title(col);
#     plt.legend(['-50k','+50k']);

# %%
# # interestingly enough 'age' contains zeroes
# print(train.loc[train.age == 0].shape)
# # ... and there are almost 3000 instances! is this a mistake?

# # Minors included? Are any making 50k a year?
# for n in np.arange(19):
#     nAge = np.sum(train.age == n)
#     nAge50k = np.sum(((train.age == n) & (train.target == 50000)))
#     n
#     print("{:5} individual(s) of age {:5} and {:5} make(s) +50k".format(nAge, n, nAge50k))
# # dang!

# %%
# what's unique about 50k+ people?
# Features I think are important:
# - tax filer (eng)
# - weeks worked
# - wage per hour
# - has dividends from stocks (eng)
# - citizenship
# - capital gains/losses
# - education
# - age bin (eng)
# - married
# - race
# - sex
# - [major industry code] 
# - employment stat
# - veterans benefits

# %%
# tax filer
# train.groupby(['major industry code','target'])[['target']].count()
# Joint both under 65 is most prevalent

# %%
# education
plt.figure(figsize=(20,6));
sns.boxplot(x='detailed occupation recode', y='weeks worked in year', hue='target', data=train);
plt.xticks(rotation='90');

# %%
# plt.figure(figsize=(20,6));
# sns.countplot(x='veterans benefits', data=train, hue='target');

# %%
# education
plt.figure(figsize=(20,6));
sns.boxplot(x='weeks worked in year', y='age', hue='target', data=train);
plt.xticks(rotation='90');

# %%
train.loc[train['wage per hour'] == 0].shape
# Out:
# (207206, 28)

# %%
# sns.heatmap(train.corr(), linewidths=0.5, cmap='coolwarm');

# %%
# Hypotheses so far:

# Important features are ...
# - tax filer (eng)
# - weeks worked
# - wage per hour
# - has dividends from stocks (eng)
# - citizenship
# - capital gains/losses
# - education
# - age bin (eng)
# - married
# - race
# - sex
# - [major industry code] 
# - employment stat
# - veterans benefits

# clean up the last variables with NAs
for col in ['country of birth self','country of birth mother','country of birth father']:
    train[col] = train[col].fillna('Unk')
    test[col] = test[col].fillna('Unk')

# Feature Engineering

# age bins
buckets = np.linspace(0, 100, 15)
labels = np.arange(14).tolist()
train['ageBinned'] = pd.cut(train.age, bins=buckets, labels=labels)
test['ageBinned'] = pd.cut(test.age, bins=buckets, labels=labels)

# tax filer
train['is_taxfiler'] = train['tax filer stat'].apply(lambda x: 'Yes' if x != ' Nonfiler' else 'No')
test['is_taxfiler'] = test['tax filer stat'].apply(lambda x: 'Yes' if x != ' Nonfiler' else 'No')

# dividends from stocks

# if the individual has dividends totally more than 50k
train['stockDividends50k'] = train['dividends from stocks'].apply(lambda x: 'Yes' if x > 50000 else 'No')
train['stockDividendsPos'] = train['dividends from stocks'].apply(lambda x: 'Yes' if x > 0 else 'No')

# stock bins // wait on it
# train.loc['']

# first generation US (neither parents born in US)
firstgen = train.loc[(train['country of birth father'] != ' United-States') &
          (train['country of birth mother'] != ' United-States') &
            (train['country of birth self'] == ' United-States')].index

train['1stGenUS'] = 'No'
train.loc[firstgen,'1stGenUS'] = 'Yes'

# second generation US (at least 1 parent born in US)
secondgen = train.loc[(train['country of birth father'] == ' United-States') |
          (train['country of birth mother'] == ' United-States')].index

train['2ndGenUS'] = 'No'
train.loc[secondgen,'2ndGenUS'] = 'Yes'

# gains over loesses
def gainsLoss(row):
    return 'No' if row['capital gains'] <= row['capital losses'] else 'Yes'
train['gainsOvLosses'] = train.apply(lambda row: gainsLoss(row), axis=1)

# fi
train['married_sex_race'] = train['marital stat'] + '|' + train['race'] + '|' + train['sex']

# agebin * weeks worked 
train['fi_age*weeksworked'] = train['ageBinned'] * train['weeks worked in year']

# hispanic origin
# ---

# citizenship
# train['US_citizen'] = // wait on it

# weeks * wage
# train['weeks*wage'] = (train['weeks worked in year'])

# %%
tset = train[feats]
tset.head(5)
# Out:
#                                     married_sex_race  fi_age*weeksworked  \
# 0                             Widowed| White| Female                   0
# 1                              Divorced| White| Male                 416
# 2   Never married| Asian or Pacific Islander| Female                   0
# 5   Married-civilian spouse present| Amer Indian ...                 312
# 6       Married-civilian spouse present| White| Male                 260
#
#   gainsOvLosses ageBinned 2ndGenUS 1stGenUS is_taxfiler stockDividends50k  \
# 0            No        10      Yes       No          No                No
# 1            No         8      Yes       No         Yes                No
# 2            No         2       No       No          No                No
# 5            No         6      Yes       No         Yes                No
# 6           Yes         5      Yes       No         Yes                No
#
#   stockDividendsPos      sex                      marital stat  \
# 0                No   Female                           Widowed
# 1                No     Male                          Divorced
# 2                No   Female                     Never married
# 5                No   Female   Married-civilian spouse present
# 6                No     Male   Married-civilian spouse present
#
#                      education full or part time employment stat  target
# 0         High school graduate                Not in labor force  -50000
# 1   Some college but no degree          Children or Armed Forces  -50000
# 2                   10th grade                Not in labor force  -50000
# 5   Some college but no degree               Full-time schedules  -50000
# 6   Bachelors degree(BA AB BS)          Children or Armed Forces  -50000

# %%
tset = pd.get_dummies(tset)
tset.shape
# Out:
# (224036, 128)

# %%
tset['target'] = tset['target'].map({50000:1,-50000:0})
tset.target[:5]
# Out:
# 0    0
# 1    0
# 2    0
# 5    0
# 6    0
# Name: target, dtype: int64

# %%
# undersample
us_0 = tset.loc[tset.target == 0].sample(20000, replace=True, random_state=33)
samp_1 = tset.loc[tset.target == 1]

tset_f = pd.concat([us_0,samp_1], ignore_index=True)
tset_f.tail()
# Out:
#        fi_age*weeksworked  target  \
# 38563                 260       1
# 38564                 312       1
# 38565                 416       1
# 38566                 312       1
# 38567                 260       1
#
#        married_sex_race_ Divorced| Amer Indian Aleut or Eskimo| Female  \
# 38563                                                  0
# 38564                                                  0
# 38565                                                  0
# 38566                                                  0
# 38567                                                  0
#
#        married_sex_race_ Divorced| Amer Indian Aleut or Eskimo| Male  \
# 38563                                                  0
# 38564                                                  0
# 38565                                                  0
# 38566                                                  0
# 38567                                                  0
#
#        married_sex_race_ Divorced| Asian or Pacific Islander| Female  \
# 38563                                                  0
# 38564                                                  0
# 38565                                                  0
# 38566                                                  0
# 38567                                                  0
#
#        married_sex_race_ Divorced| Asian or Pacific Islander| Male  \
# 38563                                                  0
# 38564                                                  0
# 38565                                                  0
# 38566                                                  0
# 38567                                                  0
#
#        married_sex_race_ Divorced| Black| Female  \
# 38563                                          0
# 38564                                          0
# 38565                                          0
# 38566                                          0
# 38567                                          0
#
#        married_sex_race_ Divorced| Black| Male  \
# 38563                                        0
# 38564                                        0
# 38565                                        0
# 38566                                        0
# 38567                                        0
#
#        married_sex_race_ Divorced| Other| Female  \
# 38563                                          0
# 38564                                          0
# 38565                                          0
# 38566                                          0
# 38567                                          0
#
#        married_sex_race_ Divorced| Other| Male  \
# 38563                                        0
# 38564                                        0
# 38565                                        0
# 38566                                        0
# 38567                                        0
#
#                                  ...                             \
# 38563                            ...
# 38564                            ...
# 38565                            ...
# 38566                            ...
# 38567                            ...
#
#        education_ Prof school degree (MD DDS DVM LLB JD)  \
# 38563                                                  0
# 38564                                                  0
# 38565                                                  0
# 38566                                                  0
# 38567                                                  0
#
#        education_ Some college but no degree  \
# 38563                                      0
# 38564                                      0
# 38565                                      0
# 38566                                      0
# 38567                                      1
#
#        full or part time employment stat_ Children or Armed Forces  \
# 38563                                                  0
# 38564                                                  0
# 38565                                                  0
# 38566                                                  0
# 38567                                                  1
#
#        full or part time employment stat_ Full-time schedules  \
# 38563                                                  1
# 38564                                                  1
# 38565                                                  1
# 38566                                                  0
# 38567                                                  0
#
#        full or part time employment stat_ Not in labor force  \
# 38563                                                  0
# 38564                                                  0
# 38565                                                  0
# 38566                                                  0
# 38567                                                  0
#
#        full or part time employment stat_ PT for econ reasons usually FT  \
# 38563                                                  0
# 38564                                                  0
# 38565                                                  0
# 38566                                                  0
# 38567                                                  0
#
#        full or part time employment stat_ PT for econ reasons usually PT  \
# 38563                                                  0
# 38564                                                  0
# 38565                                                  0
# 38566                                                  0
# 38567                                                  0
#
#        full or part time employment stat_ PT for non-econ reasons usually FT  \
# 38563                                                  0
# 38564                                                  0
# 38565                                                  0
# 38566                                                  1
# 38567                                                  0
#
#        full or part time employment stat_ Unemployed full-time  \
# 38563                                                  0
# 38564                                                  0
# 38565                                                  0
# 38566                                                  0
# 38567                                                  0
#
#        full or part time employment stat_ Unemployed part- time
# 38563                                                  0
# 38564                                                  0
# 38565                                                  0
# 38566                                                  0
# 38567                                                  0
#
# [5 rows x 128 columns]

# %%
kf = KFold(10, shuffle=True, random_state=33)
# for c in [0.1, 0.5, 1.0, 2.0, 5.0]:
X, y = tset_f.loc[:,tset_f.columns != 'target'], tset_f.target
lr = LogisticRegression(random_state=33)
# lr = RandomForestClassifier(n_estimators=50, random_state=33)
scores = cross_val_score(lr, X, y, scoring='recall', cv=kf)
print(scores,'\n',np.mean(scores))
# Out:
# [0.83253589 0.82400869 0.82758621 0.83184446 0.83169935 0.83864004
#  0.82174888 0.83516484 0.83901416 0.82299947]
#  0.8305241971204051

# %%
# test set

# %%
# pcat = PCA(2, random_state=33).fit_transform(tset_f)
# plt.scatter(x=pcat[:,1], y=pcat[:,0], c=tset_f.target.values);
